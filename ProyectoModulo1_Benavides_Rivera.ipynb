# %% [markdown]
# <img style="float: left; margin: 30px 15px 15px 15px;" src="https://pngimage.net/wp-content/uploads/2018/06/logo-iteso-png-5.png" width="300" height="500" />
#
#
# ## <font color='navy'> SIMULACIÓN DE PROCESOS FINANCIEROS
#
# **Nombres:**
# Daniela Benavides Herrera y Juan Pablo Rivera Sahagún.
#
# **Fecha:** 6 de noviembre de 2020.
#
# **Expediente** : 714983 y 714314
#
# **Profesor:** Oscar David Jaramillo Zuluaga.
#
# **Enlace Github:** https://github.com/danielabenavides/proyecto_modulo1
#
# ## Proyecto 2do Módulo

# %% [markdown]
# #  <font color='midnightblue'> Análisis de Órdenes de Servicio
#
# En el presente proyecto se pretende analizar específicamente los tiempos de una empresa llamada *EXEL PITSS SA de CV*, la cual está enfocada al servicio al cliente. Esta empresa mexicana es la principal mayorista de servicios administrados de impresión en México. Su objetivo es proporcionar soporte técnico especializado y certificado a distribuidores y fabricantes, facilitando que el servicio que prestan a su cliente final sea siempre de la más alta calidad, con la seguridad de tener EXEL PITSS como aliado estratégico del negocio. Los 2 tipos de servicios que ofrecen principalmente son:
#
# - **Servicios profesionales** como logística, formación, instalación y configuración de equipos y,
# - **Servicios gestionados** como la atención en sitio, mantenimiento preventivo y correctivo, administración de repuestos y/o consumibles, y call center dedicado.
#
# ![exelpitss1.png](attachment:exelpitss1.png)
#
# Entonces, se podría decir que tanto distrbuidores como fabricantes contratan los servicios de *EXEL PITSS*, que simultáneamente tienen contratos con el mercado, sin embargo, *EXEL PITSS* no tiene contacto directo con el mercado, si no, a través de sus clientes, como se muestra a continuación:
#
# ![exelpitss2.png](attachment:exelpitss2.png)
#
# Por lo tanto, consideramos importante analizar los tiempos transcurridos de atención al cliente, los tiempos de respuesta, tiempos de mano de obra, los tiempos de solución total, entre otros factores importantes. A continuación se puede observar un diagrama de flujo del análisis que estaremos realizando en este proyecto.
#
# ![Diagrama%20de%20flujo.png](attachment:Diagrama%20de%20flujo.png)

# %% [markdown]
# ## <font color='midnightblue'> Objetivos
#
# > Consideramos como **objetivo general** estimar cuánto tiempo le lleva a esta empresa instalar o atender cierta cantidad de órdenes de servicio mediante el análisis de sus bases de datos, para que a su vez, ellos puedan ofrecer esta información en futuros y grandes proyectos.
#
# > Como **objetivos específicos** decidimos importante incluir los siguientes:
# - Estimar cuáles son las rutas de servicio e ingenieros más rápidos.
# - Estimar el tiempo invertido con el cliente o tiempo de mano de obra.
# - Estimar tiempos de respuesta totales según la categoría de la orden de servicio.

# %% [markdown]
# ## <font color='midnightblue'> Definición del problema
#
# *EXEL PITSS* al ser la empresa mayorista principal de servicios administrados de impresión en todo México; al tener cerca de 100 ingenieros de servicio cubriendo la atención necesaria y completa en 26 de los 32 estados de la república y gestionando alrededor de 12.000 impresoras multifuncionales de 30 clientes diferentes; la convierte en una empresa con grandes responsabilidades, expectativas y compromisos los cuales tiene que cumplir para seguirse manteniendo a lo alto, cumpliendo con todos los estándares de calidad y de servicio. Esto conlleva a la empresa a dedicarle mucho tiempo y esfuerzo en mantener sus estadísticas al margen de lo que prometen cumplir. Esto quiere decir que *EXEL PITSS*  para llamar la atención de futuros clientes potenciales y para mantener contentos y satisfechos a los actuales, ofrece sus mejores resultados como un ejemplo del excelente trabajo y servicio que ellos pueden ofrecerles y garantizarles, sin embargo, lo que ofrecen son datos históricos, y creemos que pudiera ser aún más atractivo para sus clientes, que *EXEL PITSS* pudiera ofrecerles datos estimados futuros de lo que pudieran llegar a hacer en proyectos más grandes, dando a entender que tienen grandes capacidades y habilidades de atender y cumplir con cualquier reto o proyecto que se les presente. De esta manera, podría hacer crecer a *EXEL PITSS* notoriamente, para incluso tener la capacidad de poder aventurar sus posibilidades y comenzar a expandirse a otros países de América. Si bien, ofrecer sus servicios de manera internacional presenta grandes cuestionamientos o retos, sin embargo pretendemos ofrecer a la empresa información y estimaciones valiosas para poder hacer de este sueño, algo realidad.
#
# Lo más importante para los clientes de esta empresa mexicana, son los **tiempos**, ya que *EXEL PITSS* está actuando bajo el nombre de sus clientes, por lo que es importante que los clientes puedan presumir a *EXEL PITSS* por sus tiempos récord de atención al cliente, desde el momento de la llamada o subida de la orden de servicio, hasta que se atiende y por último, hasta que la orden es resuelta. Por esto es que comenzaremos por analizar cada uno de estos tiempos, qué es lo que afecta a cada uno de ellos, para de esta manera hacer buenas estimaciones para cualquier caso.

# %% [markdown]
# ## <font color='midnightblue'> Nodos y variables a simular
#
# 1. Estimar los **tiempos de mano de obra** según el **IS** de visita de la orden de servicio.
#     * Decidimos escoger estas variables o nodos ya que van de la mano, y el tiempo de mano de obra depende directamente del ingeniero de servicio, de sus habilidades, de los cursos que haya tomado y de su experiencia.
# 2. Estimar los **tiempos de respuesta** dependiendo la **ruta** de la orden de servicio.
#     - El tiempo de respuesta es el tiempo que le toma al ingeniero de servicio llegar a atender la orden desde el momento que esta cae, entonces esto depende de la ruta de servicio, o en otras palabras, el estado de la República correspondiente, ya que si este es un estado de gran movimiento vehicular, este tiempo se va a ver afectado por esto mismo.
# 3. Estimar los **tiempos totales de solución** según el **número total de visitas**.
#     - El número de visitas y el tiempo de solución son factores de mucha importancia, ya que son los que más afectados se ven en los resultados finales y los que más impacto tienen.
# 4. Estimar los **tiempos frente al cliente** según su **categoría**.
#     - Dependiendo del tipo de orden de servicio que caiga, analizar si ésta requiere de más o menos tiempo de mano de obra.

# %% [markdown]
# ## <font color='midnightblue'> Definición de hipótesis y supuestos
#
# > Con base en los datos, nuestra **hipótesis** es que existe una gran dependencia entre los nodos o variables que decidimos analizar, por lo que gracias a esto, podemos optimizar los tiempos de nuestro cliente *EXEL PITSS* para que de esta manera la empresa pudiera disminuir costos y aumentar sus utilidades consiguiendo más clientes y conservando a sus clientes actuales felices y satisfechos por el trabajo resultante.
#
# > Para los **supuestos**, establecimos los siguientes:
# - Los tiempos de respuesta excluyen accidentes de tráfico, o cualquier otro percance que se pudiera presentar relacionados con el automóvil y el IS correspondiente.
# - Ignoramos restricciones de circulación o reglas de tránsito que varían según la ruta de servicio (p.e. el estado de México),
#
# </p>

# %% [markdown]
# ### <font color='midnightblue'> Prueba de Kolmogorov-Smirnov
#
#
# La prueba KS es una prueba no paramétrica y sin distribución: no hace suposiciones sobre la distribución de datos. La prueba KS se puede utilizar para comparar una muestra con una distribución de probabilidad de referencia o para comparar dos muestras.
#
#
# Suponga que tenemos observaciones `x1, x2,… xn` que creemos que provienen de una distribución P. La prueba KS se usa para evaluar:
#
# - Hipótesis nula $H_0$: Las muestras provienen de P
# - Alternative Hypothesis $H_a$: Las muestras no provienen de P

# %% [markdown]
# ## <font color='midnightblue'> Obtención de base de datos

# %% [markdown]
# La siguiente base de datos fue proporcionada directamente por la empresa, la cual contiene todas las órdenes de servicio desde el 30 de septiembre de 2019 hasta finales de septiembre del presente año. Cada orden incluye diferente tipo de información, la cual se menciona a continuación:
#
# - **No. de orden:** número identificador de la orden
# - **No. de serie:** número de serie del equipo del cual es la orden
# - **Modelo:** modelo del equipo
# - **Num. Cliente:** número identificador del cliente
# - **Fecha recepción:** fecha en la que cayó la orden de servicio
# - **Estatus:** estatus de la orden (si se resolvió o no)
# - **Categoría:** qué tipo de servicio se va a proporcionar
# - **Ruta:** Estado de la República Mexicana a la cual pertenece
# - **Técnico de visita:** nombre del ingeniero de servicio (IS) que atendió la orden de servicio
# - **No. de visitas:** visitas que realizó el igeniero de servicio (IS) antes de ser resuelta la orden de servicio
# - **Fecha cierre:** fecha en la que se resolvió la orden de servicio
# - **T. transcurrido total:** tiempo en total que transcurrió desde que cayó la orden hasta que se cerró
# - **Tiempo frente al cliente:** tiempo de mano de obra
# - **T. respuesta:** tiempo que transcurrió desde que cayó la orden hasta que el ingeniero de servicio (IS) llegó a atenderla
# - **Límite T. respuesta:** tiempo máximo acordado que debe tardar en llegar el ingeniero de servicio (IS) a atender la orden
# - **TST:** tiempo de solución total para EXEL PITSS
# - **Límite TST:** límite de tiempo de solución total para EXEL PITSS
# - **TR OK:** 0 si no se resolvió dentro del límite del tiempo, y 1 si sí se resolvió dentro del límite de tiempo
# - **Alcance TR:** es el resultado: 2-TR/TR límite
# - **Alcance TST:** es el resultado: 2-TST/TST límite
# - **Cerrados en primera visita:** 1 si la orden fue cerrada en la primera visita, 0 si no.

# %% [markdown]
# ## <font color='midnightblue'> Librerías a utilizar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from sklearn.neighbors import KernelDensity
from scipy.stats import loglaplace 
from scipy.stats.distributions import norm
from sklearn.model_selection import GridSearchCV
from scipy.stats import gaussian_kde
from statsmodels.nonparametric.kernel_density import KDEMultivariate
from statsmodels.nonparametric.kde import KDEUnivariate
import matplotlib
from collections import defaultdict
from time import time
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm
from IPython.display import Markdown as md
from scipy.stats import cosine
from scipy.stats import logistic
from scipy.stats import dgamma
from scipy.stats import ncf

# %% [markdown]
# ## <font color='midnightblue'> Funciones a utilizar

# %%
def kde_scipy_f(x, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return lambda x: kde.evaluate(x)

def kde_sklearn_f(x, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = lambda x_grid: np.exp(kde_skl.score_samples(x_grid[:, np.newaxis]))
    return log_pdf

def kde_scipy(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scipy"""
    # Note that scipy weights its bandwidth by the covariance of the
    # input data.  To make the results comparable to the other methods,
    # we divide the bandwidth by the sample standard deviation here.
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1), **kwargs)
    return kde.evaluate(x_grid)


def kde_statsmodels_u(x, x_grid, bandwidth=0.2, **kwargs):
    """Univariate Kernel Density Estimation with Statsmodels"""
    kde = KDEUnivariate(x)
    kde.fit(bw=bandwidth, **kwargs)
    return kde.evaluate(x_grid)
    
    
def kde_statsmodels_m(x, x_grid, bandwidth=0.2, **kwargs):
    """Multivariate Kernel Density Estimation with Statsmodels"""
    kde = KDEMultivariate(x, 
                          bw='cv_ml',  #bandwidth * np.ones_like(x),
                          var_type='c', **kwargs)
    return kde.pdf(x_grid)


def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)


kde_funcs = [kde_statsmodels_u, kde_statsmodels_m, kde_scipy, kde_sklearn]
kde_funcnames = ['Statsmodels-U', 'Statsmodels-M', 'Scipy', 'Scikit-learn']

print( "Package Versions:")
import sklearn; print( "  scikit-learn:", sklearn.__version__)
import scipy; print ("  scipy:", scipy.__version__)
import statsmodels; print( "  statsmodels:", statsmodels.__version__)
# Out:
# Package Versions:
#   scikit-learn: 0.23.1
#   scipy: 1.5.0
#   statsmodels: 0.11.1

# %%
functions = dict(zip(kde_funcnames, kde_funcs))


def plot_scaling(N=1000, bandwidth=0.1, rtol=0.0,
                 Nreps=3, kwds=None, xgrid=None):
    """
    Plot the time scaling of KDE algorithms.
    Either N, bandwidth, or rtol should be a 1D array.
    """
    if xgrid is None:
        xgrid = np.linspace(-10, 10, 5000)
    if kwds is None:
        kwds=dict()
    for name in functions:
        if name not in kwds:
            kwds[name] = {}
    times = defaultdict(list)
    
    B = np.broadcast(N, bandwidth, rtol)
    assert len(B.shape) == 1
    
    for N_i, bw_i, rtol_i in B:
        x = np.random.normal(size=int(N_i))
        kwds['Scikit-learn']['rtol'] = rtol_i
        for name, func in functions.items():
            t = 0.0
            for i in range(Nreps):
                t0 = time()
                func(x, xgrid, bw_i, **kwds[name])
                t1 = time()
                t += (t1 - t0)
            times[name].append(t / Nreps)
            
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    plot_kwds={'linewidth':3, 'alpha':0.5}
    
    if np.size(N) > 1:
        for name in kde_funcnames:
            ax.loglog(N, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Number of points')
    elif np.size(bandwidth) > 1:
        for name in kde_funcnames:
            ax.loglog(bandwidth, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Bandwidth')
    elif np.size(rtol) > 1:
        for name in kde_funcnames:
            ax.loglog(rtol, times[name], label=name, **plot_kwds)
        ax.set_xlabel('Relative Tolerance')
        
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')
    ax.legend(loc=0)
    ax.set_ylabel('time (seconds)')
    ax.set_title('Execution time for KDE '
                 '({0} evaluations)'.format(len(xgrid)))
    
    return times


def plot_scaling_vs_kernel(kernels, N=1000, bandwidth=0.1, rtol=0.0,
                           Nreps=3, kwds=None, xgrid=None):
    """
    Plot the time scaling for Scikit-learn kernels.
    Either N, bandwidth, or rtol should be a 1D array.
    """
    if xgrid is None:
        xgrid = np.linspace(-10, 10, 5000)
    if kwds is None:
        kwds=dict()
    times = defaultdict(list)
    
    B = np.broadcast(N, bandwidth, rtol)
    assert len(B.shape) == 1
    
    for N_i, bw_i, rtol_i in B:
        x = np.random.normal(size=int(N_i))
        for kernel in kernels:
            kwds['kernel'] = kernel
            kwds['rtol'] = rtol_i
            t = 0.0
            for i in range(Nreps):
                t0 = time()
                kde_sklearn(x, xgrid, bw_i, **kwds)
                t1 = time()
                t += (t1 - t0)
            times[kernel].append(t / Nreps)
            
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    plot_kwds={'linewidth':3, 'alpha':0.5}
    
    if np.size(N) > 1:
        for kernel in kernels:
            ax.loglog(N, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Number of points')
    elif np.size(bandwidth) > 1:
        for kernel in kernels:
            ax.loglog(bandwidth, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Bandwidth')
    elif np.size(rtol) > 1:
        for kernel in kernels:
            ax.loglog(rtol, times[kernel], label=kernel, **plot_kwds)
        ax.set_xlabel('Relative Tolerance')
        
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')
    ax.legend(loc=0)
    ax.set_ylabel('time (seconds)')
    ax.set_title('Execution time for KDE '
                 '({0} evaluations)'.format(len(xgrid)))
    
    return times


def plot_kernels():
    """Visualize the KDE kernels available in Scikit-learn"""
    fig, ax = plt.subplots(figsize=(8, 6),
                           subplot_kw={'facecolor':'#EEEEEE',
                                       'axisbelow':True})
    ax.grid(color='white', linestyle='-', linewidth=2)
    for spine in ax.spines.values():
        spine.set_color('#BBBBBB')

    X_src = np.zeros((1, 1))
    x_grid = np.linspace(-3, 3, 1000)

    for kernel in ['gaussian', 'tophat', 'epanechnikov',
                   'exponential', 'linear', 'cosine']:
        log_dens = KernelDensity(kernel=kernel).fit(X_src).score_samples(x_grid[:, None])
        ax.plot(x_grid, np.exp(log_dens), lw=3, alpha=0.5, label=kernel)
    ax.set_ylim(0, 1.05)
    ax.set_xlim(-2.9, 2.9)
    ax.legend()
    
    
    
# Función de aceptación y rechazo usando compresión de listas
def Acep_rechazo(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1) #Evalua f en el vector R1
    t_x = t(R1) #Evalua t en el vector R1
    condition = R2*t_x <=f_x
    [plt.plot(R1[i],R2[i]*t_x[i],'ob') if condition[i] else plt.plot(R1[i],R2[i]*t_x[i],'o') \
         for i in range(len(R1))]
                
    plt.show()
    
    
# Definimos la función para que nos diga el porcentaje de aceptadas en ambos casos
def histograma(R2:'Variables distruidas U~U(0,1)',
                 R1:'Variables distribuidas como g(x)',
                 f:'función objetivo a generar',
                 t:'función que mayora a f'):
#     R1 = np.random.rand(N)
    f_x = f(R1) #Evalua f en el vector R1
    t_x = t(R1) #Evalua t en el vector R1
    condition = R2*t_x <=f_x
    barras = [R1[i] for i in range(len(R1)) if condition[i]]
    plt.hist(barras,50,density=True)
    plt.xlabel('valores aleatorios')
    plt.ylabel('probabilidad')
    plt.title('histograma función creada')
    plt.show()
    return

# %% [markdown]
# ### <font color='midnightblue'> Base de datos

# %%
data = pd.read_csv('data/ordenes_servicio.csv', encoding='latin1')
data.head(10)
# Out:
#    No. Orden N° de serie   Modelo  N° de equipo  Num. Cliente  \
# 0      94830  09HB331426  B405_DN         16851         41888
# 1      94829  09HB331586  B405_DN         16945         41888
# 2      94828  09HB331608  B405_DN         16852         41888
# 3      94827  09HB331507  B405_DN         17047         41888
# 4      94826  0Y4X849031  B405_DN         16693         41888
# 5      94825  09HB331503  B405_DN         16979         41888
# 6      94824  09HB331586  B405_DN         16945         41888
# 7      94823  09HB331608  B405_DN         16852         41888
# 8      94822  02TX062449  C8035_F         16812         41888
# 9      94821  02TX062470  C8035_F         16814         41888
#
#     Fecha recepción   Estatus                 Categoría     Ruta  \
# 0  30/09/2019 23:59  RESUELTA               CONSUMIBLES  JALISCO
# 1  30/09/2019 22:15  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 2  30/09/2019 21:39  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 3  30/09/2019 21:37  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 4  30/09/2019 21:34  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 5  30/09/2019 21:32  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 6  30/09/2019 21:29  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 7  30/09/2019 21:26  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 8  30/09/2019 21:18  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
# 9  30/09/2019 21:14  RESUELTA  MANTENIMIENTO PREVENTIVO  JALISCO
#
#           Técnico de visita  ...  T. transcurrido total  \
# 0  CARLOS GUITIERREZ/800196  ...              10.500000
# 1       HECTOR MARIN/800207  ...               0.000000
# 2       HECTOR MARIN/800207  ...               0.000000
# 3       HECTOR MARIN/800207  ...               0.666667
# 4       HECTOR MARIN/800207  ...               0.000000
# 5       HECTOR MARIN/800207  ...               0.000000
# 6       HECTOR MARIN/800207  ...               0.583333
# 7       HECTOR MARIN/800207  ...               0.000000
# 8       HECTOR MARIN/800207  ...               0.000000
# 9       HECTOR MARIN/800207  ...               0.000000
#
#   Tiempo frente al cliente  T. respuesta  Límite T. respuesta  TST  \
# 0                 0.500000           0.0                    5  0.0
# 1                 0.500000           0.0                    5  0.0
# 2                 0.666667           0.0                    5  0.0
# 3                 0.666667           0.0                    5  0.0
# 4                 0.750000           0.0                    5  0.0
# 5                 0.666667           0.0                    5  0.0
# 6                 0.583333           0.0                    5  0.0
# 7                 0.533333           0.0                    5  0.0
# 8                 0.500000           0.0                    5  0.0
# 9                 0.583333           0.0                    5  0.0
#
#    Límite TST  TR OK  Alcance TR  Alcance TST  Cerrados en primera visita
# 0          48      1         1.0          1.0                           1
# 1          48      1         1.0          1.0                           1
# 2          48      1         1.0          1.0                           1
# 3          48      1         1.0          1.0                           1
# 4          48      1         1.0          1.0                           1
# 5          48      1         1.0          1.0                           1
# 6          48      1         1.0          1.0                           1
# 7          48      1         1.0          1.0                           1
# 8          48      1         1.0          1.0                           1
# 9          48      1         1.0          1.0                           1
#
# [10 rows x 22 columns]

# %%
tiempoT= pd.DataFrame(data,columns=['T. transcurrido total'])
tiempoC= pd.DataFrame(data,columns=['Tiempo frente al cliente'])
tiempoR= pd.DataFrame(data,columns=['T. respuesta'])
TST= pd.DataFrame(data,columns=['TST'])
limiteR= pd.DataFrame(data,columns=['Límite T. respuesta'])
limiteS= pd.DataFrame(data,columns=['Límite TST'])
TROK= pd.DataFrame(data,columns=['TR OK'])
cerrados= pd.DataFrame(data,columns=['Cerrados en primera visita'])
Tiempos=tiempoT.join(tiempoC).join(tiempoR).join(cerrados).join(TST).join(limiteS).join(limiteR).join(TROK)
Tiempos.head(10)
# Out:
#    T. transcurrido total  Tiempo frente al cliente  T. respuesta  \
# 0              10.500000                  0.500000           0.0
# 1               0.000000                  0.500000           0.0
# 2               0.000000                  0.666667           0.0
# 3               0.666667                  0.666667           0.0
# 4               0.000000                  0.750000           0.0
# 5               0.000000                  0.666667           0.0
# 6               0.583333                  0.583333           0.0
# 7               0.000000                  0.533333           0.0
# 8               0.000000                  0.500000           0.0
# 9               0.000000                  0.583333           0.0
#
#    Cerrados en primera visita  TST  Límite TST  Límite T. respuesta  TR OK
# 0                           1  0.0          48                    5      1
# 1                           1  0.0          48                    5      1
# 2                           1  0.0          48                    5      1
# 3                           1  0.0          48                    5      1
# 4                           1  0.0          48                    5      1
# 5                           1  0.0          48                    5      1
# 6                           1  0.0          48                    5      1
# 7                           1  0.0          48                    5      1
# 8                           1  0.0          48                    5      1
# 9                           1  0.0          48                    5      1

# %% [markdown]
# ## <font color='midnightblue'> Estandarización de datos

# %%
Tiempos=tiempoT.join(tiempoC).join(tiempoR).join(TST)
Tiempos.head(80)
TST= pd.DataFrame(data,columns=['TST'])
promedio = Tiempos.mean()
des = Tiempos.std()
data_estd = (Tiempos - promedio)/des
data_estd.head(10)
# Out:
#    T. transcurrido total  Tiempo frente al cliente  T. respuesta       TST
# 0              -0.180376                 -0.336437      -0.27994 -0.297862
# 1              -0.332195                 -0.336437      -0.27994 -0.297862
# 2              -0.332195                 -0.228733      -0.27994 -0.297862
# 3              -0.322556                 -0.228733      -0.27994 -0.297862
# 4              -0.332195                 -0.174881      -0.27994 -0.297862
# 5              -0.332195                 -0.228733      -0.27994 -0.297862
# 6              -0.323761                 -0.282585      -0.27994 -0.297862
# 7              -0.332195                 -0.314896      -0.27994 -0.297862
# 8              -0.332195                 -0.336437      -0.27994 -0.297862
# 9              -0.332195                 -0.282585      -0.27994 -0.297862

# %%
plt.figure(figsize=(16,8))
plt.subplot(131)
plt.scatter(np.arange(0,len(tiempoT)),tiempoT,color='dodgerblue')
plt.title('Tiempo total transcurrido',size=18)
plt.ylabel('Tiempo en horas')
plt.subplot(132)
plt.ylabel('Tiempo en horas')
plt.scatter(np.arange(0,len(tiempoC)),tiempoC,color='darkblue')
plt.title('Tiempo frente al cliente',size=18)
plt.subplot(133)
plt.scatter(np.arange(0,len(tiempoR)),tiempoR,color='cornflowerblue')
plt.title('Tiempo de respuesta',size=18)
plt.ylabel('Tiempo en horas')
# Out:
# Text(0, 0.5, 'Tiempo en horas')

# %% [markdown]
# # <font color='midnightblue'> 1. Tiempos de mano de obra e ingeniero de servicio
#
# - En este primer conjunto de datos observamos los tiempos de mano de obra promedio de cada ingeniero de servicio.

# %%
IS = data.groupby(['Técnico de visita']).mean()
prom_TC = IS['Tiempo frente al cliente']
prom_TC.head(10)
# Out:
# Técnico de visita
# ALBERTO ANTONIO TENORIO/500018         1.141215
# ALBERTO NAVARRO VARGAS                 0.842462
# ALDO TOMAS RUIZ FLORES                 1.549265
# ALEJANDRO HINOJOSA/500169              1.223504
# ALEJANDRO NEZAHUALCOYOTL CRUZ PEREZ    0.788053
# ALFREDO TORRES/500158                  1.506252
# ANDRES ALBERTO RAMIREZ BELTRAN         0.000000
# ANDRES ALVARO PEREZ GARCIA             1.695604
# ANTONIO  ARANDA VAZQUEZ/500114         0.565104
# ARMANDO SERRANO ESQUIVEL               1.718067
# Name: Tiempo frente al cliente, dtype: float64

# %%
def kde_sklearn(x, x_grid, bandwidth=0.2, **kwargs):
    """Kernel Density Estimation with Scikit-learn"""
    kde_skl = KernelDensity(bandwidth=bandwidth, **kwargs)
    kde_skl.fit(x[:, np.newaxis])
    # score_samples() returns the log-likelihood of the samples
    log_pdf = kde_skl.score_samples(x_grid[:, np.newaxis])
    return np.exp(log_pdf)

# %% [markdown]
# > Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.

# %%
x_grid = np.linspace(-2, 6, 1000)
x = prom_TC

fig, ax = plt.subplots(figsize=(8,6))
for bandwidth in [0.1, 0.3, 1.0]:
    ax.plot(x_grid, kde_sklearn(x, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, alpha=0.7)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.set_xlim(-2, 6)
ax.legend(loc='upper right')

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=30) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper right')
ax.set_xlim(-2, 6);
# Out:
# {'bandwidth': 0.19310344827586207}

# %% [markdown]
# ## <font color='midnightblue'> Método de aceptación y rechazo

# %%
# Función objetivo 
x_grid = np.linspace(-2, 6, 1000)
data1 = np.asarray(prom_TC)
f = lambda x: kde_sklearn(x, x_grid, bandwidth=0.19310344827586207)
# Máximo de la función f
max_f = f(data1).max()
# Función t
t = lambda x: max_f*np.ones(len(x))
x = np.linspace(0,6,1000)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.figure(figsize=(10,8))
plt.plot(x,f(data1),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 1000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(0,6,N)

Acep_rechazo(R2,R1,f,t)
# Out:
# El máximo de f es: 0.5350380758231796

# %% [markdown]
# > En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.

# %%
# Función objetivo 
f = lambda x: kde_sklearn(x, x_grid, bandwidth=0.19310344827586207)
x = np.linspace(0,6,1000) # Rango donde se graficará las funciones
# Gráfica de la función
plt.figure(figsize=(10,8))
plt.plot(x,f(data1),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(0,6,N)
histograma(R2, R1, f, t)

# %% [markdown]
# > Y aquí observamos que efectivamente escogimos el mejor bandwidth.

# %% [markdown]
# ## <font color='midnightblue'> Distribuciones de probabilidad
#
# > A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos.

# %%
dist_to = ['norm','crystalball','dgamma','dweibull','fisk','gennorm','hypsecant','rdist','skewnorm','t','vonmises_line']
e = []

fig, ax = plt.subplots(figsize=(8,6))
ax.set_title('Funciones de densidad de probabilidad',size=15)
ax.set_xlim(-1, 6)
[y, x, _] = ax.hist(prom_TC, bins=20, density=True, label='prom_TC',fc='lightgray')
x = x[1:]

for dist in dist_to:
    param = getattr(st,dist).fit(prom_TC)
    
    pdf = getattr(st, dist).pdf(x, *param)
    
    ax.plot(x,pdf,linewidth=3,label='pdf = '+ str(dist))
    #plt.plot(x,pdf,label='pdf = {dist}'.format(dist_to))
    plt.legend();
    
    e.append(((y-pdf)**2).mean())
    
e
# Out:
# [0.012830480480540645,
#  0.012830480768136967,
#  0.01527603648754072,
#  0.014368855331133204,
#  0.01674500896038121,
#  0.01489883099673657,
#  0.015766254723414128,
#  0.01257095258817804,
#  0.015775622499310752,
#  0.014751138612870498,
#  0.01404715739665319]

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según sus menores errores resultantes son:
# - **NORM**
# - **CRYSTALBALL**
# - **RDIST**

# %% [markdown]
# ### <font color='midnightblue'> Prueba de Kolmogorov-Smirnov
#
# - Las hipótesis nulas $H_0$ son las siguientes:

# %%
h0 = ['H_0$ = La PDF es {}'.format(dist) for dist in dist_to]
h0
# Out:
# ['H_0$ = La PDF es norm',
#  'H_0$ = La PDF es crystalball',
#  'H_0$ = La PDF es dgamma',
#  'H_0$ = La PDF es dweibull',
#  'H_0$ = La PDF es fisk',
#  'H_0$ = La PDF es gennorm',
#  'H_0$ = La PDF es hypsecant',
#  'H_0$ = La PDF es rdist',
#  'H_0$ = La PDF es skewnorm',
#  'H_0$ = La PDF es t',
#  'H_0$ = La PDF es vonmises_line']

# %% [markdown]
# - Las hipótesis alternas $H_a$ son las siguientes:

# %%
ha = ['H_a$ = La PDF no es {}'.format(dist) for dist in dist_to]
ha
# Out:
# ['H_a$ = La PDF no es norm',
#  'H_a$ = La PDF no es crystalball',
#  'H_a$ = La PDF no es dgamma',
#  'H_a$ = La PDF no es dweibull',
#  'H_a$ = La PDF no es fisk',
#  'H_a$ = La PDF no es gennorm',
#  'H_a$ = La PDF no es hypsecant',
#  'H_a$ = La PDF no es rdist',
#  'H_a$ = La PDF no es skewnorm',
#  'H_a$ = La PDF no es t',
#  'H_a$ = La PDF no es vonmises_line']

# %%
results = []
for i in dist_to:
    dist = getattr(st, i)
    param = dist.fit(prom_TC)
    a = st.kstest(prom_TC, i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# dgamma: statistic=0.060907163860983105, pvalue=0.5835715039176629
# dweibull: statistic=0.06233457294561582, pvalue=0.5540204343800483
# gennorm: statistic=0.06264219351335426, pvalue=0.5477143024176281
# vonmises_line: statistic=0.06264730208460478, pvalue=0.5476097851625233
# t: statistic=0.06389811610698526, pvalue=0.5222390454962517
# hypsecant: statistic=0.06405970601691047, pvalue=0.5189954600519329
# rdist: statistic=0.06998355625003602, pvalue=0.40680047993405044
# crystalball: statistic=0.07083428365829336, pvalue=0.3919127968174433
# norm: statistic=0.07083449617354531, pvalue=0.39190911967134046
# skewnorm: statistic=0.07322925885765696, pvalue=0.3518312878399268
# fisk: statistic=0.0754929377876674, pvalue=0.31649990033780995

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según la prueba de Kolmogorov-Smirnov son las de:
# - **DGAMMA**
# - **LOGISTIC**
# - **EXPONNORM**
#
# Por lo que no rechazamos las pruebas de hipótesis en las que establecimos estas distribuciones de probabilidad.

# %% [markdown]
# ## <font color='midnightblue'> Ajuste de Distribuciones Hipotéticas
#
# > A continuación, para nuestro primer nodo, utilizaremos el método Q-Q para las mejores distribuciones de probabilidad para nuestro primer conjunto de datos.

# %% [markdown]
# ### <font color='midnightblue'> DGAMMA

# %%
measurements = prom_TC
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'dgamma'
params = getattr(st, dist).fit(measurements)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements.min(), measurements.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> LOGISTIC

# %%
measurements = prom_TC
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'logistic'
params = getattr(st, dist).fit(measurements)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements.min(), measurements.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> EXPONNORM

# %%
measurements = prom_TC
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'exponnorm'
params = getattr(st, dist).fit(measurements)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements.min(), measurements.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1605: RuntimeWarning: divide by zero encountered in log
#   return exparg + np.log(0.5 * invK * sc.erfc(-(x - invK) / np.sqrt(2)))
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1610: RuntimeWarning: overflow encountered in exp
#   return _norm_cdf(x) - np.exp(expval) * _norm_cdf(x - invK)
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1610: RuntimeWarning: invalid value encountered in multiply
#   return _norm_cdf(x) - np.exp(expval) * _norm_cdf(x - invK)
# C:\Users\Daniela\anaconda3\lib\site-packages\numpy\lib\function_base.py:2167: RuntimeWarning: invalid value encountered in ? (vectorized)
#   outputs = ufunc(*inputs)
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:130: RuntimeWarning: invalid value encountered in double_scalars
#   slope = r_num / ssxm
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_stats_mstats_common.py:142: RuntimeWarning: divide by zero encountered in double_scalars
#   sterrest = np.sqrt((1 - r**2) * ssym / ssxm / df)

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **LOGISTIC**

# %% [markdown]
# ## <font color='midnightblue'> Estimación de los Parámetros

# %%
params = st.logistic.fit(prom_TC)
# Separate parts of parameters
arg = params[:-2]
loc1 = params[-2]
scale1 = params[-1]

print('loc=',loc1,'scale=',scale1)
# Out:
# loc= 1.2820356264578923 scale= 0.47099615182310667

# %% [markdown]
# ##  <font color='midnightblue'> La prueba chi cuadrado - Usando el histograma
#
# > Volveremos a comprobar lo antes planteado mediante la prueba de chi cuadrado.

# %%
np.random.seed(555)
mu_real = prom_TC.mean()
sigma_real = prom_TC.std()
N = 100 # Cantidad de muestras
n1 = np.random.logistic(loc1, scale1, N)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='indigo')
plt.title('Histograma de datos con distribución Logistic',size=13)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media mu =1.187908, desviación estándar muestral =1.013896

# %% [markdown]
# ### <font color='midnightblue'> Resolver prueba de hipótesis
# > $H_0$: la distribución es logistic con `loc`=1.282 y `scale`=0.47
#
# > $H_a$: los datos no se distribuyen como logistic

# %%
pi = st.logistic.pdf(x, loc1, scale1)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  -242.91876343387543
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=-242.91876343387543, pvalue=1.0)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  1.1879077818319514
# Desviación estándar muestral =  1.0138958023660705

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > No podemos rechazar la $H_0$ por lo tanto los datos distribuyen logistic.

# %% [markdown]
# ## <font color='midnightblue'> Método de muestreo estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
montecarlo_standar = st.logistic.ppf(np.random.rand(N),loc1,scale1)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,30,density=True,color='mediumaquamarine')
plt.title('Montecarlo estándar')
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.logistic.ppf(v)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,30,density=True,color='lightseagreen')
plt.title('Muestreo estratificado')
plt.show()

# %% [markdown]
# ## <font color='midnightblue'> Intervalos de confianza

# %%
np.random.seed(55555)
#media = 10; sd = 20
N = 100
confianza = 0.95
X = np.random.logistic(loc1,scale1,N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.logistic.interval(confianza, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (1.1581228394148597, 1.4764819743074649)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (1.0234009976929879, 1.6112038160293367)
# Media calculada 1.3173024068611623

# %% [markdown]
# # <font color='midnightblue'> 2. Tiempos de respuesta y ruta de servicio
#
# - En este segundo conjunto de datos observamos los tiempos de respuesta promedio según la ruta de servicio.

# %%
RS = data.groupby(['Ruta']).mean()
prom_TR = RS['T. respuesta']
prom_TR.head(10)
# Out:
# Ruta
# AGUASCALIENTES          5.122173
# BAJA CALIFORNIA         8.148684
# BAJA CALIFORNIA SUR     5.670231
# CAMPECHE                8.926812
# CHIAPAS                10.044872
# CHIHUAHUA               1.349420
# CIUDAD DE MEXICO        2.478623
# COAHUILA                1.490839
# COLIMA                  3.192903
# DURANGO                 1.455022
# Name: T. respuesta, dtype: float64

# %% [markdown]
# > Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.

# %%
> Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.x_grid = np.linspace(-2, 12, 1000)
x = prom_TR

fig, ax = plt.subplots(figsize=(8,6))
for bandwidth in [0.15, 0.6, 1.0]:
    ax.plot(x_grid, kde_sklearn(x, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, alpha=.7)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.set_xlim(-2,12)
ax.legend(loc='upper right')

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-2,12);
# Out:
# {'bandwidth': 1.0}

# %% [markdown]
# ## <font color='midnightblue'> Método de aceptación y rechazo

# %%
# Función objetivo 
x_grid = np.linspace(-2, 12, 1000)
data2 = np.asarray(prom_TR)
f = lambda x: kde_sklearn(x, x_grid, bandwidth=1)
# Máximo de la función f
max_f = f(data2).max()
# Función t
t = lambda x: max_f*np.ones(len(x))
x = np.linspace(0,12,1000)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.figure(figsize=(10,8))
plt.plot(x,f(data2),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 1000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(0,12,N)

Acep_rechazo(R2,R1,f,t)
# Out:
# El máximo de f es: 0.15259865191399527

# %% [markdown]
# > En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.

# %%
> En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.# Función objetivo 
f = lambda x: kde_sklearn(x, x_grid, bandwidth=0.19310344827586207)
x = np.linspace(0,12,1000) # Rango donde se graficará las funciones
# Gráfica de la función
plt.figure(figsize=(10,8))
plt.plot(x,f(data2),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(0,12,N)
histograma(R2, R1, f, t)

# %% [markdown]
# > Y aquí observamos que efectivamente escogimos el mejor bandwidth.

# %% [markdown]
# ## <font color='midnightblue'> Distribuciones de probabilidad
#
# > A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos.

# %%
dist_to = ['alpha','beta','betaprime','burr12','cosine','dgamma','exponnorm','exponweib','pearson3','loggamma','logistic', 'lognorm']
e = []

plt.figure(figsize=(8,6))

[y, x, _] = plt.hist(prom_TR, bins=10, density=True, label='prom_TR',fc='lightgray')
x = x[1:]

for dist in dist_to:
    param = getattr(st,dist).fit(prom_TR)
    
    pdf = getattr(st, dist).pdf(x, *param)
    
    plt.plot(x, pdf, linewidth=3,label='pdf estimada = '+ str(dist))
    
    plt.legend();
    
    e.append(((y-pdf)**2).mean())
    
e
# Out:
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:667: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:671: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1035: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1035: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# [0.0027571280199689867,
#  0.0026431927250444125,
#  0.002736119540445936,
#  0.002627500134556387,
#  0.0025138176624235667,
#  0.0029637436183728356,
#  0.002784199630641402,
#  0.0026224572506396413,
#  0.0027355056036510996,
#  0.0025037263233512537,
#  0.0027341148109430113,
#  0.0027344625786002294]

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según sus menores errores resultantes son:
# - **LOGGAMMA**
# - **COSINE**
# - **EXPONWEIB**

# %% [markdown]
# ### <font color='midnightblue'> Prueba de Kolmogorov-Smirnov
#
# - Las hipótesis nulas $H_0$ son las siguientes:

# %%
h0 = ['H_0$ = La PDF es {}'.format(dist) for dist in dist_to]
h0
# Out:
# ['H_0$ = La PDF es alpha',
#  'H_0$ = La PDF es beta',
#  'H_0$ = La PDF es betaprime',
#  'H_0$ = La PDF es burr12',
#  'H_0$ = La PDF es cosine',
#  'H_0$ = La PDF es dgamma',
#  'H_0$ = La PDF es exponnorm',
#  'H_0$ = La PDF es exponweib',
#  'H_0$ = La PDF es pearson3',
#  'H_0$ = La PDF es loggamma',
#  'H_0$ = La PDF es logistic',
#  'H_0$ = La PDF es lognorm']

# %% [markdown]
# - Las hipótesis alternas $H_a$ son las siguientes:

# %%
ha = ['H_a$ = La PDF no es {}'.format(dist) for dist in dist_to]
ha
# Out:
# ['H_a$ = La PDF no es alpha',
#  'H_a$ = La PDF no es beta',
#  'H_a$ = La PDF no es betaprime',
#  'H_a$ = La PDF no es burr12',
#  'H_a$ = La PDF no es cosine',
#  'H_a$ = La PDF no es dgamma',
#  'H_a$ = La PDF no es exponnorm',
#  'H_a$ = La PDF no es exponweib',
#  'H_a$ = La PDF no es pearson3',
#  'H_a$ = La PDF no es loggamma',
#  'H_a$ = La PDF no es logistic',
#  'H_a$ = La PDF no es lognorm']

# %%
results = []
for i in dist_to:
    dist = getattr(st, i)
    param = dist.fit(prom_TR)
    a = st.kstest(prom_TR, i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2316: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:667: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:671: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1035: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# exponweib: statistic=0.08194064249039446, pvalue=0.9764042874283451
# beta: statistic=0.08213023937415248, pvalue=0.9758646831913695
# burr12: statistic=0.0888375025577548, pvalue=0.9512460559362634
# alpha: statistic=0.09758532033508899, pvalue=0.9024643274425889
# betaprime: statistic=0.09765724391593272, pvalue=0.9019878073653317
# pearson3: statistic=0.09815869652399456, pvalue=0.8986333287334692
# lognorm: statistic=0.0989832892529885, pvalue=0.892996372697486
# logistic: statistic=0.10629503225221848, pvalue=0.8370289434328944
# loggamma: statistic=0.10688459694187732, pvalue=0.8320994036626354
# exponnorm: statistic=0.10827849141049051, pvalue=0.8202326482757851
# cosine: statistic=0.11836838316989062, pvalue=0.7151327604004958
# dgamma: statistic=0.12390699408173084, pvalue=0.6503290902001816

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según la prueba de Kolmogorov-Smirnov son las de:
# - **EXPONWEIB**
# - **BETA**
# - **BURR12**
#
# Por lo que no rechazamos las pruebas de hipótesis en las que establecimos estas distribuciones de probabilidad.

# %% [markdown]
# ## <font color='midnightblue'> Ajuste de Distribuciones Hipotéticas
#
# > A continuación, para nuestro segundo nodo, utilizaremos el método Q-Q para las mejores distribuciones de probabilidad para nuestro segundo conjunto de datos.

# %% [markdown]
# ### <font color='midnightblue'> EXPONWEIB

# %%
measurements2 = prom_TR
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'exponweib'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> COSINE

# %%
measurements2 = prom_TR
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'cosine'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> BETA

# %%
measurements2 = prom_TR
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'beta'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()
# Out:
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\Juan Pablo\Anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:515: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **COSINE**

# %% [markdown]
# ## <font color='midnightblue'> Estimación de los Parámetros

# %%
params = st.cosine.fit(prom_TR)
# Separate parts of parameters
arg = params[:-2]
loc2 = params[-2]
scale2 = params[-1]

print('loc=',loc2,'scale=',scale2)
# Out:
# loc= 4.6016724858579 scale= 2.1141780573851676

# %% [markdown]
# ##  <font color='midnightblue'> La prueba chi cuadrado - Usando el histograma
#
# > Volveremos a comprobar lo antes planteado mediante la prueba de chi cuadrado.

# %%
np.random.seed(555)
mu_real = prom_TR.mean()
sigma_real = prom_TR.std()
N = 100 # Cantidad de muestras
n1 = cosine.rvs(loc2, scale2, size=1000)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='indigo')
plt.title('Histograma de datos con distribución Cosine',size=13)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media mu =4.359120, desviación estándar muestral =3.592929

# %% [markdown]
# ### <font color='midnightblue'> Resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es cosine con `loc`=4.601 y `scale`=2.11
#
# > $H_a$: los datos no se distribuyen cosine

# %%
pi = st.cosine.pdf(x, loc2, scale2)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  31.106599090277882
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=31.106599090277882, pvalue=0.9999999983756948)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  4.359120189538152
# Desviación estándar muestral =  3.5929289163672555

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > No podemos rechazar la $H_0$ por lo tanto los datos distribuyen cosine.

# %% [markdown]
# ## <font color='midnightblue'> Método de muestreo estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
montecarlo_standar = st.cosine.ppf(np.random.rand(N),loc2,scale2)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,30,density=True,color='mediumaquamarine')
plt.title('Montecarlo estándar')
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.cosine.ppf(v)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,30,density=True,color='lightseagreen')
plt.title('Muestreo estratificado')
plt.show()

# %% [markdown]
# ## <font color='midnightblue'> Intervalos de confianza

# %%
np.random.seed(55555)
#media = 10; sd = 20
N = 100
confianza = 0.95
X = cosine.rvs(loc2,scale2,N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.cosine.interval(confianza, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (4.210917448077032, 5.123412645477593)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (4.174003660423549, 5.160326433131076)
# Media calculada 4.6671650467773125

# %% [markdown]
# # <font color='midnightblue'> 3. Tiempos totales de solución y ruta de servicio
#
# - En este tercer conjunto de datos observamos los tiempos totales de solución promedio según la ruta de servicio.

# %%
NV = data.groupby(['Ruta']).mean()
prom_TT = NV['T. transcurrido total']
prom_TT.head(10)
# Out:
# Ruta
# AGUASCALIENTES         20.597081
# BAJA CALIFORNIA        52.314035
# BAJA CALIFORNIA SUR    38.760963
# CAMPECHE               90.793478
# CHIAPAS                47.215065
# CHIHUAHUA              13.301872
# CIUDAD DE MEXICO       21.386747
# COAHUILA               13.283731
# COLIMA                 17.699579
# DURANGO                16.008010
# Name: T. transcurrido total, dtype: float64

# %% [markdown]
# > Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.

# %%
> Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.x_grid = np.linspace(5, 50, 1000)
x = prom_TT

fig, ax = plt.subplots(figsize=(8,6))
for bandwidth in [1.6, 2, 2.6]:
    ax.plot(x_grid, kde_sklearn(x, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, alpha=.7)
ax.hist(x, 20, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.set_xlim(5,50)
ax.legend(loc='upper right')

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.1, 1.0, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper right')
ax.set_xlim(5, 50);
# Out:
# {'bandwidth': 1.0}

# %% [markdown]
# ## <font color='midnightblue'> Método de aceptación y rechazo

# %%
# Función objetivo 
x_grid = np.linspace(5, 50, 1000)
data3 = np.asarray(prom_TT)
f = lambda x: kde_sklearn(x, x_grid, bandwidth=1)
# Máximo de la función f
max_f = f(data3).max()
# Función t
t = lambda x: max_f*np.ones(len(x))
x = np.linspace(5,50,1000)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.figure(figsize=(10,8))
plt.plot(x,f(data3),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 1000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(5,50,N)

Acep_rechazo(R2,R1,f,t)
# Out:
# El máximo de f es: 0.057773036012276964

# %% [markdown]
# > En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.

# %%
> En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.# Función objetivo 
f = lambda x: kde_sklearn(x, x_grid, bandwidth=1)
x = np.linspace(0,10,1000) # Rango donde se graficará las funciones
# Gráfica de la función
plt.figure(figsize=(10,8))
plt.plot(x,f(data),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(0,10,N)
histograma(R2, R1, f, t)

# %% [markdown]
# > Y aquí observamos que efectivamente escogimos el mejor bandwidth.

# %% [markdown]
# ## <font color='midnightblue'> Distribuciones de probabilidad
#
# > A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos.

# %%
dist_to = ['alpha','burr','fisk','invgamma','betaprime','exponnorm','f','lognorm','mielke','ncf','powerlognorm',]
e = []

plt.figure(figsize=(8,6))

[y, x, _] = plt.hist(prom_TT, bins=10, density=True, label='prom_TT',fc='lightgray')
x = x[1:]

for dist in dist_to:
    param = getattr(st,dist).fit(prom_TT)
    
    pdf = getattr(st, dist).pdf(x, *param)
    
    plt.plot(x, pdf, linewidth=3,label='pdf estimada = '+ str(dist))
    
    plt.legend();
    
    e.append(((y-pdf)**2).mean())
    
e
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:781: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:785: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1722: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))
# [1.5894882807362874e-05,
#  1.8091566239558517e-05,
#  1.6419697839382525e-05,
#  1.6444890430870422e-05,
#  1.6269346513936383e-05,
#  2.3625338249164177e-05,
#  1.6280775830540193e-05,
#  1.5024033536930554e-05,
#  2.0182297637049075e-05,
#  1.709033217553963e-05,
#  1.572692400563501e-05]

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según sus menores errores resultantes son:
# - **LOGNORM**
# - **POWERLOGNORM**
# - **ALPHA**

# %% [markdown]
# ### <font color='midnightblue'> Prueba de Kolmogorov-Smirnov

# %% [markdown]
# - Las hipótesis nulas $H_0$ son las siguientes:

# %%
h0 = ['H_0$ = La PDF es {}'.format(dist) for dist in dist_to]
h0
# Out:
# ['H_0$ = La PDF es alpha',
#  'H_0$ = La PDF es burr',
#  'H_0$ = La PDF es fisk',
#  'H_0$ = La PDF es genpareto',
#  'H_0$ = La PDF es invgamma',
#  'H_0$ = La PDF es lomax',
#  'H_0$ = La PDF es nct',
#  'H_0$ = La PDF es pareto',
#  'H_0$ = La PDF es wald']

# %% [markdown]
# - Las hipótesis alternas $H_a$ son las siguientes:

# %%
ha = ['H_a$ = La PDF no es {}'.format(dist) for dist in dist_to]
ha
# Out:
# ['H_a$ = La PDF no es alpha',
#  'H_a$ = La PDF no es burr',
#  'H_a$ = La PDF no es fisk',
#  'H_a$ = La PDF no es genpareto',
#  'H_a$ = La PDF no es invgamma',
#  'H_a$ = La PDF no es lomax',
#  'H_a$ = La PDF no es nct',
#  'H_a$ = La PDF no es pareto',
#  'H_a$ = La PDF no es wald']

# %%
results = []
for i in dist_to:
    dist = getattr(st, i)
    param = dist.fit(prom_TT)
    a = st.kstest(prom_TT, i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# exponnorm: statistic=0.07754805074545085, pvalue=0.9768520720614916
# ncf: statistic=0.07831124984924989, pvalue=0.9746357310687042
# powerlognorm: statistic=0.07971275767750613, pvalue=0.9702082587887927
# lognorm: statistic=0.08080108933768904, pvalue=0.9664437397379548
# fisk: statistic=0.08224934015511329, pvalue=0.9609826220220601
# invgamma: statistic=0.08257110568954279, pvalue=0.9596984955590082
# mielke: statistic=0.08260380559886044, pvalue=0.9595665453926852
# betaprime: statistic=0.0826617786871035, pvalue=0.9593319555248497
# f: statistic=0.08267103555377076, pvalue=0.9592944194391283
# burr: statistic=0.08276255257617574, pvalue=0.9589221682020429
# alpha: statistic=0.09036755176303982, pvalue=0.9206227377294584

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según la prueba de Kolmogorov son:
# - **EXPONNORM**
# - **NCF**
# - **POWERLOGNORM**

# %% [markdown]
# ## <font color='midnightblue'> Ajuste de Distribuciones Hipotéticas
#
# > A continuación, para nuestro tercer nodo, utilizaremos el método Q-Q para las mejores distribuciones de probabilidad para nuestro tercer conjunto de datos.

# %% [markdown]
# ### <font color='midnightblue'> NCF

# %%
measurements2 = prom_TT
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'ncf'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1722: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1722: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))

# %% [markdown]
# ### <font color='midnightblue'> POWERLOGNORM

# %%
measurements2 = prom_TT
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'powerlognorm'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:6411: RuntimeWarning: divide by zero encountered in power
#   pow(_norm_cdf(-np.log(x)/s), c*1.0-1.0))
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:6411: RuntimeWarning: overflow encountered in power
#   pow(_norm_cdf(-np.log(x)/s), c*1.0-1.0))
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:6410: RuntimeWarning: invalid value encountered in multiply
#   return (c/(x*s) * _norm_pdf(np.log(x)/s) *

# %% [markdown]
# ### <font color='midnightblue'> LOGNORM

# %%
measurements2 = prom_TT
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'lognorm'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **NCF**

# %% [markdown]
# ## <font color='midnightblue'> Estimación de los Parámetros

# %%
params = st.ncf.fit(prom_TT)
# Separate parts of parameters
arg = params[:-2]
loc3 = params[-2]
scale3 = params[-1]

dfn = arg[0]
dfd = arg[1]
nc = arg[2]
print('dfn=',dfn,'dfd=',dfd,'nc=',nc,'loc=',loc3,'scale=',scale3)
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1722: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))
# dfn= 32.133404909004085 dfd= 7.525456613245049 nc= 36.50635053117454 loc= -0.14829271038403885 scale= 11.316221790339103

# %% [markdown]
# ##  <font color='midnightblue'> La prueba chi cuadrado - Usando el histograma
#
# > Volveremos a comprobar lo antes planteado mediante la prueba de chi cuadrado.

# %%
np.random.seed(555)
mu_real = prom_TT.mean()
sigma_real = prom_TT.std()
N = 1000 # Cantidad de muestras
n1 = st.ncf.rvs(dfn,dfd,nc,loc3,scale3,N)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='indigo')
plt.title('Histograma de datos con distribución NCF',size=13)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media mu =110.522027, desviación estándar muestral =61.747716

# %% [markdown]
# ### <font color='midnightblue'> Resolver la siguiente prueba de hipótesis
# > $H_0$: la distribución es invgamma con `dfn`= 32.13 `dfd`= 7.52 `nc`= 36.50 `loc`= -0.14 `scale`= 11.31
#
# > $H_a$: los datos no se distribuyen invgamma

# %%
pi = st.ncf.pdf(x,dfn,dfd,nc)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.90, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  1.4053980310929859
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=1.4053980310929859, pvalue=1.0)
# Estadístico de chi_cuadrado =  104.2750373330777
# Media muestral =  25.277898629832062
# Desviación estándar muestral =  11.536153096171677

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > No podemos rechazar la $H_0$ por lo tanto los datos distribuyen ncf.

# %% [markdown]
# ## <font color='midnightblue'> Metodo de Muestreo Estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
q = np.random.rand(N)
montecarlo_standar = st.ncf.ppf(q,dfn,dfd,nc)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,120,density=True,color='mediumaquamarine')
plt.title('Montecarlo estándar')
plt.xlim((0,10))
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.ncf.ppf(v,dfn,dfd,nc)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,120,density=True,color='lightseagreen')
plt.title('Muestreo estratificado')
plt.xlim((0,10))
plt.show()

# %% [markdown]
# ## <font color='midnightblue'> Intervalos de Confianza

# %%
np.random.seed(55555)
#media = 10; sd = 20
N = 100
confianza = 0.95
X = ncf.rvs(dfn,dfd,nc,loc3,scale3,size=N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.ncf.interval(confianza,dfn,dfd,nc, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (27.852556566101516, 35.40954198938643)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (33.23332399646698, 48.01300303575178)
# Media calculada 31.631049277743976

# %% [markdown]
# # <font color='midnightblue'> 4. Categoría y tiempos frente al cliente
#
# - En este cuarto y último conjunto de datos observamos los tiempos frente al cliente promediosegún la categoría.

# %%
CT = data.groupby(['Categoría']).mean()
prom_CT2 = CT['Tiempo frente al cliente']
prom_CT2.head(10)
# Out:
# Categoría
# APOYO VIA TELEFONICA                0.146677
# AUDITORIA DE SERVICIO               1.349174
# CAMBIO DE UBICACION                 0.962393
# CONFIGURACION                       1.061440
# CONSUMIBLE DEFECTUOSO - GARANTIA    0.099612
# CONSUMIBLE PROACTIVO                0.105703
# CONSUMIBLES                         0.108180
# CORRECTIVO                          1.595566
# GARANTIA DE SERVICIO                1.355420
# INSTALACION CAMBIO                  1.965495
# Name: Tiempo frente al cliente, dtype: float64

# %% [markdown]
# > Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.

# %%
> Utilizamos Kernel Density Estimation para visualizar los datos y escoger el mejor bandwidth.x_grid = np.linspace(-2, 12, 1000)
x = prom_CT2

fig, ax = plt.subplots(figsize=(8,6))
for bandwidth in [0.05, 0.09, .30]:
    ax.plot(x_grid, kde_sklearn(x, x_grid, bandwidth=bandwidth),
            label='bw={0}'.format(bandwidth), linewidth=3, alpha=.7)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.set_xlim(-1,3)
ax.legend(loc='upper right')

# %%
grid = GridSearchCV(KernelDensity(),
                    {'bandwidth': np.linspace(0.015, .02, 30)},
                    cv=20) # 20-fold cross-validation
grid.fit(x[:, None])
print(grid.best_params_)

kde = grid.best_estimator_
pdf = np.exp(kde.score_samples(x_grid[:, None]))

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x_grid, pdf, linewidth=3, alpha=0.5, label='bw=%.2f' % kde.bandwidth)
ax.hist(x, 30, fc='gray', histtype='stepfilled', alpha=0.3, density=True)
ax.legend(loc='upper left')
ax.set_xlim(-1,3);
# Out:
# {'bandwidth': 0.02}

# %% [markdown]
# ## <font color='midnightblue'> Método de aceptación y rechazo

# %%
# Función objetivo 
data4 = np.asarray(prom_CT2)
f = lambda x: kde_sklearn(x, x_grid, bandwidth=0.02)
# Máximo de la función f
max_f = f(data4).max()
# Función t
t = lambda x: max_f*np.ones(len(x))
x = np.linspace(0,3,1000)  # Rango donde se graficará las funciones
print('El máximo de f es:',max_f)
# Gráficas de las funciones
plt.figure(figsize=(10,8))
plt.plot(x,f(data4),label='f(x)')
plt.plot(x,t(x),label='t(x)')
plt.legend()

# Validación del método
N = 1000 # número de puntos a simular
R2 = np.random.rand(N)
R1 = np.random.uniform(0,3,N)

Acep_rechazo(R2,R1,f,t)
# Out:
# El máximo de f es: 3.5399186382716814

# %% [markdown]
# > En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.

# %%
> En la gráfica superior podemos observar las 10,000 muestras aleatorias generadas con el método de aceptación y rechazo según la distribución de probabilidad obtenida con el Kernel Density Estimation.# Función objetivo 
f = lambda x: kde_sklearn(x, x_grid, bandwidth=0.19310344827586207)
x = np.linspace(0,6,1000) # Rango donde se graficará las funciones
# Gráfica de la función
plt.figure(figsize=(10,8))
plt.plot(x,f(data4),label='f(x)')
plt.legend()

t = lambda x: max_f*np.ones(len(x))
N = 1000
R2 = np.random.rand(N)
R1 = np.random.uniform(0,6,N)
histograma(R2, R1, f, t)

# %% [markdown]
# > Y aquí observamos que efectivamente escogimos el mejor bandwidth.

# %% [markdown]
# ## <font color='midnightblue'> Distribuciones de probabilidad
#
# > A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos.

# %%
dist_to = ['burr','dgamma','dweibull','mielke','powerlaw','t','truncexpon','weibull_max','genextreme']
e = []

plt.figure(figsize=(8,6))

[y, x, _] = plt.hist(prom_CT2, bins=10, density=True, label='prom_CT2',fc='lightgray')
x = x[1:]

for dist in dist_to:
    param = getattr(st,dist).fit(prom_CT2)
    
    pdf = getattr(st, dist).pdf(x, *param)
    
    plt.plot(x, pdf, linewidth=3,label='pdf estimada = '+ str(dist))
    
    plt.legend();
    
    e.append(((y-pdf)**2).mean())
    ## <font color='midnightblue'> Método de aceptación y rechazo## <font color='midnightblue'> Distribuciones de probabilidad
    
> A continuación probaremos distintas distribuciones de probabilidad para nuestros datos, y mediante el error y la prueba de Sminorv-Kolmogrov determinaremos cuál es la que mejor se ajusta a nuestros datos. 
e
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:5266: RuntimeWarning: divide by zero encountered in log
#   return np.log(k) + np.log(x)*(k-1.0) - np.log1p(x**s)*(1.0+k*1.0/s)
# [0.140892528206198,
#  0.1597631948007747,
#  0.14287091091931578,
#  0.13943138158053892,
#  0.1751090182758702,
#  0.21614696383266888,
#  0.15261649115557013,
#  0.21140462259006626,
#  0.2114021850755273]

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según sus menores errores resultantes son:
# - **MIELKE**
# - **BURR**
# - **DWEIBULL**

# %% [markdown]
# ### <font color='midnightblue'> Prueba de Kolmogorov-Smirnov

# %% [markdown]
# - Las hipótesis nulas $H_0$ son las siguientes:

# %%
h0 = ['H_0$ = La PDF es {}'.format(dist) for dist in dist_to]
h0
# Out:
# ['H_0$ = La PDF es burr',
#  'H_0$ = La PDF es dgamma',
#  'H_0$ = La PDF es dweibull',
#  'H_0$ = La PDF es mielke',
#  'H_0$ = La PDF es powerlaw',
#  'H_0$ = La PDF es t',
#  'H_0$ = La PDF es truncexpon',
#  'H_0$ = La PDF es weibull_max',
#  'H_0$ = La PDF es genextreme']

# %% [markdown]
# - Las hipótesis alternas $H_a$ son las siguientes:

# %%
ha = ['H_a$ = La PDF no es {}'.format(dist) for dist in dist_to]
ha
# Out:
# ['H_a$ = La PDF no es burr',
#  'H_a$ = La PDF no es dgamma',
#  'H_a$ = La PDF no es dweibull',
#  'H_a$ = La PDF no es mielke',
#  'H_a$ = La PDF no es powerlaw',
#  'H_a$ = La PDF no es t',
#  'H_a$ = La PDF no es truncexpon',
#  'H_a$ = La PDF no es weibull_max',
#  'H_a$ = La PDF no es genextreme']

# %%
results = []
for i in dist_to:
    dist = getattr(st, i)
    param = dist.fit(prom_CT2)
    a = st.kstest(prom_CT2, i, args=param)
    results.append((i,a[0],a[1]))
    
    
results.sort(key=lambda x:float(x[2]), reverse=True)
for j in results:
    print("{}: statistic={}, pvalue={}".format(j[0], j[1], j[2]))
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:5266: RuntimeWarning: divide by zero encountered in log
#   return np.log(k) + np.log(x)*(k-1.0) - np.log1p(x**s)*(1.0+k*1.0/s)
# dweibull: statistic=0.12149655103953357, pvalue=0.879537731692692
# dgamma: statistic=0.13436559573863982, pvalue=0.7953924579436034
# mielke: statistic=0.1377522913510838, pvalue=0.7708784341861222
# burr: statistic=0.1383363020509733, pvalue=0.7665795405211513
# powerlaw: statistic=0.1478306485634264, pvalue=0.6945166315401015
# t: statistic=0.15474100285297293, pvalue=0.6406816866183737
# genextreme: statistic=0.15684465808645495, pvalue=0.6242774511679227
# weibull_max: statistic=0.1568512066010871, pvalue=0.6242264441148819
# truncexpon: statistic=0.16950788233492686, pvalue=0.5274290282090226

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
# Las distribuciones de probabilidad que mejor se ajustan a nuestros datos, según la prueba de Kolmogorov son:
# - **DWEIBULL**
# - **DGAMMA**
# - **MIELKE**

# %% [markdown]
# ## <font color='midnightblue'> Ajuste de Distribuciones Hipotéticas
#
# > A continuación, para nuestro cuarto nodo, utilizaremos el método Q-Q para las mejores distribuciones de probabilidad para nuestro último conjunto de datos.

# %% [markdown]
# ### <font color='midnightblue'> DWEIBULL

# %%
measurements2 = prom_CT2
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'dweibull'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> DGAMMA

# %%
measurements2 = prom_CT2
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'dgamma'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()

# %% [markdown]
# ### <font color='midnightblue'> MIELKE

# %%
measurements2 = prom_CT2
# Histograma de las variables creadas
divisiones = 10 # Cantidad de barras en el histograma
fig, ax = plt.subplots(3,1, figsize=(8,10))
fig.tight_layout(pad=3.0)

ax[0].hist(measurements2,divisiones,density=True)

# Función de distribución de probabilidad la cual creemos que mis datos distribuyen 
# RECORDAR: SÓLO FUNCIONA PARA DISTRIBUCIONES CONTINUAS
dist = 'mielke'
params = getattr(st, dist).fit(measurements2)

# Graficar PDF de la distribución que queremos probar

x = np.arange(measurements2.min(), measurements2.max(), .01)
y = getattr(st, dist).pdf(x, *params)
ax[0].plot(x,y,'r--')
ax[0].set_ylabel('Probability')
ax[0].grid()

# gráfica de Q-Q entre mis datos y la curva que quiero probar que sigue mi distribución (dist)
# Usando scipy
grap2 = st.probplot(measurements2, dist=dist, sparams=getattr(st, dist).fit(x)[:-2], plot=ax[1], fit=True)
ax[1].grid()
ax[1].set_title('Usando paquete scipy')

grap1 = sm.qqplot(measurements2, dist=dist, line='s', fit=True, ax=ax[2])
ax[2].grid()
ax[2].set_title('Usando paquete stats')

plt.xlabel(f'{dist.title()} theorical quantiles',size=20)
plt.ylabel('Data theorical quantiles')
plt.show()
# Out:
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:5266: RuntimeWarning: divide by zero encountered in log
#   return np.log(k) + np.log(x)*(k-1.0) - np.log1p(x**s)*(1.0+k*1.0/s)
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:5266: RuntimeWarning: divide by zero encountered in log
#   return np.log(k) + np.log(x)*(k-1.0) - np.log1p(x**s)*(1.0+k*1.0/s)
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:2429: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Daniela\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:5266: RuntimeWarning: divide by zero encountered in log
#   return np.log(k) + np.log(x)*(k-1.0) - np.log1p(x**s)*(1.0+k*1.0/s)

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > La distribución de probabilidad que mejor se ajusta a nuestros datos es **DGAMMA**

# %% [markdown]
# ## <font color='midnightblue'> Estimación de los Parámetros

# %%
params = dgamma.fit(prom_CT2)
# Separate parts of parameters
arg = params[:-2]
loc4 = params[-2]
scale4 = params[-1]

a = arg[0]

print('a=',a,'loc=',loc4,'scale=',scale4)
# Out:
# a= 3.4371401617663273 loc= 0.8049488146234935 scale= 0.16978266675596415

# %% [markdown]
# ##  <font color='midnightblue'> La prueba chi cuadrado - Usando el histograma
#
# > Volveremos a comprobar lo antes planteado mediante la prueba de chi cuadrado.

# %%
np.random.seed(555)
mu_real = prom_CT2.mean()
sigma_real = prom_CT2.std()
N = 100 # Cantidad de muestras
n1 = dgamma.rvs(a,loc4,scale4, size=1000)
J = 90  # Cantidad de particiones del histograma
plt.figure(figsize=(8,6))
[freq, x, _] = plt.hist(n1, J, density=True,color='indigo')
plt.title('Histograma de datos con distribución DGAMMA',size=13)
plt.show()
# Se obvia el último valor de x para obtener exactamente J muestras de x
x = x[:-1] 

# Media y desviación estándar muestral
mu = np.mean(x)
sigma = np.std(x)
print('media mu =%f, desviación estándar muestral =%f'%(mu,sigma))
# Out:
# media mu =0.874489, desviación estándar muestral =1.244994

# %% [markdown]
# ### <font color='midnightblue'> Resolver la siguiente prueba de hipótesis
# $H_0$: la distribución es dgamma con `a`=3.43 `loc`=0.80 y `scale`=0.16
#
# > $H_a$: los datos no se distribuyen dgamma

# %%
pi = st.dgamma.pdf(x, a,loc4,scale4)
# Cálculo de la esperanza usando la expresión teórica
Ei = x*pi
# Cálculo teórico de la chi cuadrada
x2 = np.sum(list(map(lambda Ei, obs_i:(obs_i - Ei)**2 / Ei, Ei, freq)))
print('Valor de chi cuadrado teorico  = ', x2)

# Cálculo usando la librería estadística de la chi cuadrada
X2 = st.chisquare(freq, Ei)
print('Valor de chi cuadrado librería = ', X2)

# Cálculo de Grados de libertad del estadístico
p = 2 # Parámetros estimados con los datos
m = J-p-1 # grados de libertad

Chi_est = st.chi2.ppf(q=0.95, df=m)
print('Estadístico de chi_cuadrado = ', Chi_est)
print('Media muestral = ', mu, '\nDesviación estándar muestral = ', sigma)
# Out:
# Valor de chi cuadrado teorico  =  -8.211521255094205
# Valor de chi cuadrado librería =  Power_divergenceResult(statistic=-8.211521255094205, pvalue=1.0)
# Estadístico de chi_cuadrado =  109.77330935028795
# Media muestral =  0.8744887399868103
# Desviación estándar muestral =  1.244993748809567

# %% [markdown]
# #### <font color='midnightblue'> Conclusión
#
# > No podemos rechazar la $H_0$ por lo tanto los datos distribuyen dgamma.

# %% [markdown]
# ## <font color='midnightblue'> Metodo de Muestreo Estratificado

# %%
N = 500
# (Método transformada inversa visto en clases pasadas)
# Método montecarlo estándar 
montecarlo_standar = st.dgamma.ppf(np.random.rand(N),a)
plt.figure(figsize=(10,8))
plt.hist(montecarlo_standar,120,density=True,color='mediumaquamarine')
plt.title('Montecarlo estándar')
plt.show()

# Método muestreo estratificado (B estratos)
B = N
U2 = np.random.rand(B)
i = np.arange(0,B)
v = (U2+i)/B
m_estratificado = st.dgamma.ppf(v,a)

plt.figure(figsize=(10,8))
plt.hist(m_estratificado,120,density=True,color='lightseagreen')
plt.title('Muestreo estratificado')
plt.show()

# %% [markdown]
# ## <font color='midnightblue'> Intervalos de Confianza

# %%
np.random.seed(55555)
#media = 10; sd = 20
N = 100
confianza = 0.95
X = dgamma.rvs(a,loc4,scale4,N)
st.sem
i1 = st.t.interval(confianza,len(X)-1, loc=np.mean(X), scale=st.sem(X))
i2 = st.dgamma.interval(confianza,a, loc=np.mean(X), scale=st.sem(X))
print('Con una confianza de %2.2f la media estará en el intervalo t,\n %s' %(confianza,i1))
print('Con una confianza de %2.2f la media estará en el intervalo normal,\n %s' %(confianza,i2))
print('Media calculada' ,np.mean(X))
# Out:
# Con una confianza de 0.95 la media estará en el intervalo t,
#  (0.6632670167200465, 0.9256767812536719)
# Con una confianza de 0.95 la media estará en el intervalo normal,
#  (0.3354455628060023, 1.2534982351677162)
# Media calculada 0.7944718989868592

# %% [markdown]
# ## <font color='midnightblue'> Referencias
#
# Kawwa, N. (2013). When to Use the Kolmogorov-Smirnov Test. noviembre 11, 2020, de Towards Data Science Sitio web: https://towardsdatascience.com/when-to-use-the-kolmogorov-smirnov-test-dd0b2c8a8f61
#
# The Scipy community. (2015). scipy.stats.logistic. noviembre 18, 2020, de Scipy.org Sitio web:
# https://docs.scipy.org/doc/scipy-0.16.1/reference/generated/scipy.stats.logistic.html
#
# The Scipy community. (2020). scipy.stats.ncf. noviembre 18, 2020, de Scipy.org Sitio web: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ncf.html
#
# The Scipy community. (2020). scipy.stats.cosine. noviembre 18, 2020, de Scipy.org Sitio web: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.cosine.html
#
# The Scipy community. (2020). scipy.stats.dgamma. noviembre 18, 2020, de Scipy.org Sitio web: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.dgamma.html
